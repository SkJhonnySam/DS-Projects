# %% [markdown]
# # Heart Attack Prediction in Indonesia

# %%
# Import necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, r2_score, confusion_matrix
from summarytools import dfSummary
from sklearn.impute import KNNImputer, SimpleImputer


# To suppress the warnings
import warnings
warnings.filterwarnings('ignore')

# model
from sklearn.linear_model import LogisticRegression

# %%
# import data
df = pd.read_csv(r"D:\Users\Data_set\heart_attack_prediction_indonesia.csv")

# %%
print("Data Shape:", df.shape)
print('\nFirst 5 rows:','\n',df.head())
print('\nDescriptive Statistics:','\n', df.describe)
# Out:
# Data Shape: (158355, 28)
#
# First 5 rows:
#     age  gender region income_level  hypertension  diabetes  cholesterol_level  \
# 0   60    Male  Rural       Middle             0         1                211
# 1   53  Female  Urban          Low             0         0                208
# 2   62  Female  Urban          Low             0         0                231
# 3   73    Male  Urban          Low             1         0                202
# 4   52    Male  Urban       Middle             1         0                232
#
#    obesity  waist_circumference  family_history  ... blood_pressure_diastolic  \
# 0        0                   83               0  ...                       62
# 1        0                  106               1  ...                       76
# 2        1                  112               1  ...                       74
# 3        0                   82               1  ...                       65
# 4        0                   89               0  ...                       75
#
#   fasting_blood_sugar cholesterol_hdl cholesterol_ldl triglycerides  \
# 0                 173              48             121           101
# 1                  70              58              83           138
# 2                 118              69             130           171
# 3                  98              52              85           146
# 4                 104              59             127           139
#
#   EKG_results  previous_heart_disease  medication_usage  \
# 0      Normal                       0                 0
# 1      Normal                       1                 0
# 2    Abnormal                       0                 1
# 3      Normal                       0                 1
# 4      Normal                       1                 0
#
#    participated_in_free_screening  heart_attack
# 0                               0             0
# 1                               1             0
# 2                               0             1
# 3                               1             0
# 4                               1             1
#
# [5 rows x 28 columns]
#
# Descriptive Statistics:
#  <bound method NDFrame.describe of         age  gender region income_level  hypertension  diabetes  \
# 0        60    Male  Rural       Middle             0         1
# 1        53  Female  Urban          Low             0         0
# 2        62  Female  Urban          Low             0         0
# 3        73    Male  Urban          Low             1         0
# 4        52    Male  Urban       Middle             1         0
# ...     ...     ...    ...          ...           ...       ...
# 158350   60  Female  Rural       Middle             0         0
# 158351   64  Female  Urban          Low             0         0
# 158352   30    Male  Urban       Middle             0         0
# 158353   74    Male  Urban       Middle             0         0
# 158354   61    Male  Urban       Middle             0         0
#
#         cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 0                     211        0                   83               0  ...
# 1                     208        0                  106               1  ...
# 2                     231        1                  112               1  ...
# 3                     202        0                   82               1  ...
# 4                     232        0                   89               0  ...
# ...                   ...      ...                  ...             ...  ...
# 158350                199        0                   79               0  ...
# 158351                179        0                   93               0  ...
# 158352                220        0                   78               0  ...
# 158353                180        0                   58               1  ...
# 158354                190        0                   81               0  ...
#
#        blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# 0                            62                 173              48
# 1                            76                  70              58
# 2                            74                 118              69
# 3                            65                  98              52
# 4                            75                 104              59
# ...                         ...                 ...             ...
# 158350                       74                  79              52
# 158351                       73                 111              41
# 158352                       87                 127              50
# 158353                       70                 119              52
# 158354                       81                  95              49
#
#        cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# 0                  121           101      Normal                       0
# 1                   83           138      Normal                       1
# 2                  130           171    Abnormal                       0
# 3                   85           146      Normal                       0
# 4                  127           139      Normal                       1
# ...                ...           ...         ...                     ...
# 158350             238           234      Normal                       0
# 158351             177           239      Normal                       0
# 158352             158           201    Abnormal                       1
# 158353             153           171      Normal                       1
# 158354             125           149    Abnormal                       0
#
#         medication_usage  participated_in_free_screening  heart_attack
# 0                      0                               0             0
# 1                      0                               1             0
# 2                      1                               0             1
# 3                      1                               1             0
# 4                      0                               1             1
# ...                  ...                             ...           ...
# 158350                 1                               0             0
# 158351                 1                               1             1
# 158352                 1                               1             1
# 158353                 0                               1             1
# 158354                 0                               1             0
#
# [158355 rows x 28 columns]>

# %%
# df summary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_1e019 thead>tr>th {
#   text-align: left;
# }
# #T_1e019_row0_col0, #T_1e019_row1_col0, #T_1e019_row2_col0, #T_1e019_row3_col0, #T_1e019_row4_col0, #T_1e019_row5_col0, #T_1e019_row6_col0, #T_1e019_row7_col0, #T_1e019_row8_col0, #T_1e019_row9_col0, #T_1e019_row10_col0, #T_1e019_row11_col0, #T_1e019_row12_col0, #T_1e019_row13_col0, #T_1e019_row14_col0, #T_1e019_row15_col0, #T_1e019_row16_col0, #T_1e019_row17_col0, #T_1e019_row18_col0, #T_1e019_row19_col0, #T_1e019_row20_col0, #T_1e019_row21_col0, #T_1e019_row22_col0, #T_1e019_row23_col0, #T_1e019_row24_col0, #T_1e019_row25_col0, #T_1e019_row26_col0, #T_1e019_row27_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_1e019_row0_col1, #T_1e019_row1_col1, #T_1e019_row2_col1, #T_1e019_row3_col1, #T_1e019_row4_col1, #T_1e019_row5_col1, #T_1e019_row6_col1, #T_1e019_row7_col1, #T_1e019_row8_col1, #T_1e019_row9_col1, #T_1e019_row10_col1, #T_1e019_row11_col1, #T_1e019_row12_col1, #T_1e019_row13_col1, #T_1e019_row14_col1, #T_1e019_row15_col1, #T_1e019_row16_col1, #T_1e019_row17_col1, #T_1e019_row18_col1, #T_1e019_row19_col1, #T_1e019_row20_col1, #T_1e019_row21_col1, #T_1e019_row22_col1, #T_1e019_row23_col1, #T_1e019_row24_col1, #T_1e019_row25_col1, #T_1e019_row26_col1, #T_1e019_row27_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_1e019_row0_col2, #T_1e019_row1_col2, #T_1e019_row2_col2, #T_1e019_row3_col2, #T_1e019_row4_col2, #T_1e019_row5_col2, #T_1e019_row6_col2, #T_1e019_row7_col2, #T_1e019_row8_col2, #T_1e019_row9_col2, #T_1e019_row10_col2, #T_1e019_row11_col2, #T_1e019_row12_col2, #T_1e019_row13_col2, #T_1e019_row14_col2, #T_1e019_row15_col2, #T_1e019_row16_col2, #T_1e019_row17_col2, #T_1e019_row18_col2, #T_1e019_row19_col2, #T_1e019_row20_col2, #T_1e019_row21_col2, #T_1e019_row22_col2, #T_1e019_row23_col2, #T_1e019_row24_col2, #T_1e019_row25_col2, #T_1e019_row26_col2, #T_1e019_row27_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_1e019_row0_col3, #T_1e019_row1_col3, #T_1e019_row2_col3, #T_1e019_row3_col3, #T_1e019_row4_col3, #T_1e019_row5_col3, #T_1e019_row6_col3, #T_1e019_row7_col3, #T_1e019_row8_col3, #T_1e019_row9_col3, #T_1e019_row10_col3, #T_1e019_row11_col3, #T_1e019_row12_col3, #T_1e019_row13_col3, #T_1e019_row14_col3, #T_1e019_row15_col3, #T_1e019_row16_col3, #T_1e019_row17_col3, #T_1e019_row18_col3, #T_1e019_row19_col3, #T_1e019_row20_col3, #T_1e019_row21_col3, #T_1e019_row22_col3, #T_1e019_row23_col3, #T_1e019_row24_col3, #T_1e019_row25_col3, #T_1e019_row26_col3, #T_1e019_row27_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_1e019_row0_col4, #T_1e019_row1_col4, #T_1e019_row2_col4, #T_1e019_row3_col4, #T_1e019_row4_col4, #T_1e019_row5_col4, #T_1e019_row6_col4, #T_1e019_row7_col4, #T_1e019_row8_col4, #T_1e019_row9_col4, #T_1e019_row10_col4, #T_1e019_row11_col4, #T_1e019_row12_col4, #T_1e019_row13_col4, #T_1e019_row14_col4, #T_1e019_row15_col4, #T_1e019_row16_col4, #T_1e019_row17_col4, #T_1e019_row18_col4, #T_1e019_row19_col4, #T_1e019_row20_col4, #T_1e019_row21_col4, #T_1e019_row22_col4, #T_1e019_row23_col4, #T_1e019_row24_col4, #T_1e019_row25_col4, #T_1e019_row26_col4, #T_1e019_row27_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_1e019_row0_col5, #T_1e019_row1_col5, #T_1e019_row2_col5, #T_1e019_row3_col5, #T_1e019_row4_col5, #T_1e019_row5_col5, #T_1e019_row6_col5, #T_1e019_row7_col5, #T_1e019_row8_col5, #T_1e019_row9_col5, #T_1e019_row10_col5, #T_1e019_row11_col5, #T_1e019_row12_col5, #T_1e019_row13_col5, #T_1e019_row14_col5, #T_1e019_row15_col5, #T_1e019_row16_col5, #T_1e019_row17_col5, #T_1e019_row18_col5, #T_1e019_row19_col5, #T_1e019_row20_col5, #T_1e019_row21_col5, #T_1e019_row22_col5, #T_1e019_row23_col5, #T_1e019_row24_col5, #T_1e019_row25_col5, #T_1e019_row26_col5, #T_1e019_row27_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_1e019">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 158,355 x 28<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_1e019_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_1e019_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_1e019_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_1e019_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_1e019_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_1e019_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e019_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1e019_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_1e019_row0_col2" class="data row0 col2" >Mean (sd) : 54.5 (11.9)<br>min < med < max:<br>25.0 < 55.0 < 90.0<br>IQR (CV) : 17.0 (4.6)</td>
#       <td id="T_1e019_row0_col3" class="data row0 col3" >66 distinct values</td>
#       <td id="T_1e019_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_1e019_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e019_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1e019_row1_col1" class="data row1 col1" ><strong>gender</strong><br>[object]</td>
#       <td id="T_1e019_row1_col2" class="data row1 col2" >1. Male<br>2. Female</td>
#       <td id="T_1e019_row1_col3" class="data row1 col3" >82,243 (51.9%)<br>76,112 (48.1%)</td>
#       <td id="T_1e019_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_1e019_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e019_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_1e019_row2_col1" class="data row2 col1" ><strong>region</strong><br>[object]</td>
#       <td id="T_1e019_row2_col2" class="data row2 col2" >1. Urban<br>2. Rural</td>
#       <td id="T_1e019_row2_col3" class="data row2 col3" >103,038 (65.1%)<br>55,317 (34.9%)</td>
#       <td id="T_1e019_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_1e019_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e019_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_1e019_row3_col1" class="data row3 col1" ><strong>income_level</strong><br>[object]</td>
#       <td id="T_1e019_row3_col2" class="data row3 col2" >1. Middle<br>2. Low<br>3. High</td>
#       <td id="T_1e019_row3_col3" class="data row3 col3" >71,230 (45.0%)<br>63,422 (40.1%)<br>23,703 (15.0%)</td>
#       <td id="T_1e019_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_1e019_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e019_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_1e019_row4_col1" class="data row4 col1" ><strong>hypertension</strong><br>[int64]</td>
#       <td id="T_1e019_row4_col2" class="data row4 col2" >Mean (sd) : 0.3 (0.5)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 1.0 (0.7)</td>
#       <td id="T_1e019_row4_col3" class="data row4 col3" >2 distinct values</td>
#       <td id="T_1e019_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_1e019_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e019_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_1e019_row5_col1" class="data row5 col1" ><strong>diabetes</strong><br>[int64]</td>
#       <td id="T_1e019_row5_col2" class="data row5 col2" >Mean (sd) : 0.2 (0.4)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 0.0 (0.5)</td>
#       <td id="T_1e019_row5_col3" class="data row5

# %%
# Finding Missing value
print("Missing Value:",'\n',df.isnull().sum())
# Out:
# Missing Value:
#  age                                   0
# gender                                0
# region                                0
# income_level                          0
# hypertension                          0
# diabetes                              0
# cholesterol_level                     0
# obesity                               0
# waist_circumference                   0
# family_history                        0
# smoking_status                        0
# alcohol_consumption               94848
# physical_activity                     0
# dietary_habits                        0
# air_pollution_exposure                0
# stress_level                          0
# sleep_hours                           0
# blood_pressure_systolic               0
# blood_pressure_diastolic              0
# fasting_blood_sugar                   0
# cholesterol_hdl                       0
# cholesterol_ldl                       0
# triglycerides                         0
# EKG_results                           0
# previous_heart_disease                0
# medication_usage                      0
# participated_in_free_screening        0
# heart_attack                          0
# dtype: int64

# %%
# Alcohol_consumption column has 63507 out of 158355
df.shape[0] - df['alcohol_consumption'].isnull().sum()

# If we use dropna or simple imputer strategy might indeed lead to biased or incorrect predictions.
# Let's try with Advanced Imputation Techniques
# Out:
# 63507

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    age  gender region income_level  hypertension  diabetes  cholesterol_level  \
# 0   60    Male  Rural       Middle             0         1                211
# 1   53  Female  Urban          Low             0         0                208
# 2   62  Female  Urban          Low             0         0                231
# 3   73    Male  Urban          Low             1         0                202
# 4   52    Male  Urban       Middle             1         0                232
#
#    obesity  waist_circumference  family_history  ... blood_pressure_diastolic  \
# 0        0                   83               0  ...                       62
# 1        0                  106               1  ...                       76
# 2        1                  112               1  ...                       74
# 3        0                   82               1  ...                       65
# 4        0                   89               0  ...                       75
#
#   fasting_blood_sugar cholesterol_hdl cholesterol_ldl triglycerides  \
# 0                 173              48             121           101
# 1                  70              58              83           138
# 2                 118              69             130           171
# 3                  98              52              85           146
# 4                 104              59             127           139
#
#   EKG_results  previous_heart_disease  medication_usage  \
# 0      Normal                       0                 0
# 1      Normal                       1                 0
# 2    Abnormal                       0                 1
# 3      Normal                       0                 1
# 4      Normal                       1                 0
#
#    participated_in_free_screening  heart_attack
# 0                               0             0
# 1                               1             0
# 2                               0             1
# 3                               1             0
# 4                               1             1
#
# [5 rows x 28 columns]

# %%
# Target value distribution
print(df['heart_attack'].value_counts())
print('')
print(df['heart_attack'].value_counts(normalize=True))
# Out:
# heart_attack
# 0    94854
# 1    63501
# Name: count, dtype: int64
#
# heart_attack
# 0    0.598996
# 1    0.401004
# Name: proportion, dtype: float64

# %%
x = df.drop(columns=['heart_attack'])
y = df['heart_attack']

Catagorical_features = x.select_dtypes(include=['object']).columns
Numerical_features = x.select_dtypes(include=['int64','float64']).columns

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,)

numerical_transformer = Pipeline(steps=[
    ('KnnImpute', KNNImputer(n_neighbors=3)),
    ('Scaler', StandardScaler())
])

catagorical_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

preprocesser = ColumnTransformer(transformers=[
    ('num',numerical_transformer,Numerical_features ),
    ('cat',catagorical_transformer,Catagorical_features)
])

# %%
model = Pipeline(steps=[
    ('preprocesser',preprocesser),
    ('classifier',LogisticRegression())
])
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy score: {accuracy:.2f}')
# Out:
# Accuracy score: 0.73

# %%
# Let's check the model

# %%
sample_data = df.sample(1)
sample_data
# Sample data patient has risk of  heart_attack
# Out:
#         age gender region income_level  hypertension  diabetes  \
# 131926   52   Male  Rural       Middle             0         0
#
#         cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 131926                165        1                  118               0  ...
#
#        blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# 131926                       73                 125              53
#
#        cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# 131926             167           123      Normal                       1
#
#         medication_usage  participated_in_free_screening  heart_attack
# 131926                 1                               1             1
#
# [1 rows x 28 columns]

# %%
# Sample data without target
sample_data_without_target = sample_data.drop(columns=['heart_attack'])
sample_data_without_target
# Out:
#         age gender region income_level  hypertension  diabetes  \
# 131926   52   Male  Rural       Middle             0         0
#
#         cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 131926                165        1                  118               0  ...
#
#        blood_pressure_systolic blood_pressure_diastolic fasting_blood_sugar  \
# 131926                     105                       73                 125
#
#        cholesterol_hdl cholesterol_ldl triglycerides  EKG_results  \
# 131926              53             167           123       Normal
#
#         previous_heart_disease  medication_usage  \
# 131926                       1                 1
#
#         participated_in_free_screening
# 131926                               1
#
# [1 rows x 27 columns]

# %%
# I got the correct result......!!!!

prediction = model.predict(sample_data_without_target)

if prediction[0] == 1:
      print("Prediction: The person is at risk of a heart attack.")
else:
    print("Prediction: The person is not at risk of a heart attack.")
# Out:
# Prediction: The person is at risk of a heart attack.
